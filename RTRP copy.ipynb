# %%
import os
import numpy as np
import librosa 
import matplotlib.pyplot as plt
import pandas as pd

# %%
features=[]
loc="spects"
for i in os.listdir(loc):
    location=loc+"/"+i
    features.append(location)

# %%
data_filepath = "modified_files.csv"
df = pd.read_csv(data_filepath)

# %%
import resampy
def extraction(path):
    x,sample_rate=librosa.load(path,res_type='kaiser_fast')
    mfcc=np.mean(librosa.feature.mfcc(y=x,sr=sample_rate,n_mfcc=40).T,axis=0)
    return mfcc

# %%
df['file_name'] = df['fil_ename'] + ".wav"
df.head(10)
# Out:
#    Unnamed: 0        country  duration_seconds   english_cname  file_id  \
# 0           0  United States                 3  Abert's Towhee    17804
# 1           1  United States                 4  Abert's Towhee   177367
# 2           2  United States                 4  Abert's Towhee   145505
# 3           3  United States                 5  Abert's Towhee   228159
# 4           4  United States                 5  Abert's Towhee    51313
# 5           5  United States                 6  Abert's Towhee   111831
# 6           6  United States                 6  Abert's Towhee   289047
# 7           7  United States                 7  Abert's Towhee   119222
# 8           8  United States                 8  Abert's Towhee   314730
# 9           9  United States                 8  Abert's Towhee   288434
#
#       file_name                                    file_url     genus  \
# 0   XC17804.wav   https://www.xeno-canto.org/17804/download  Melozone
# 1  XC177367.wav  https://www.xeno-canto.org/177367/download  Melozone
# 2  XC145505.wav  https://www.xeno-canto.org/145505/download  Melozone
# 3  XC228159.wav  https://www.xeno-canto.org/228159/download  Melozone
# 4   XC51313.wav   https://www.xeno-canto.org/51313/download  Melozone
# 5  XC111831.wav  https://www.xeno-canto.org/111831/download  Melozone
# 6  XC289047.wav  https://www.xeno-canto.org/289047/download  Melozone
# 7  XC119222.wav  https://www.xeno-canto.org/119222/download  Melozone
# 8  XC314730.wav  https://www.xeno-canto.org/314730/download  Melozone
# 9  XC288434.wav  https://www.xeno-canto.org/288434/download  Melozone
#
#    latitude                                            license  \
# 0   33.3117  http://creativecommons.org/licenses/by-nc-nd/2.5/
# 1   34.2850  http://creativecommons.org/licenses/by-nc-sa/4.0/
# 2   34.2850  http://creativecommons.org/licenses/by-nc-sa/3.0/
# 3   33.1188  http://creativecommons.org/licenses/by-nc-nd/4.0/
# 4   36.0628  http://creativecommons.org/licenses/by-nc-sa/3.0/
# 5   32.7430  http://creativecommons.org/licenses/by-nc-nd/2.5/
# 6   34.2599  http://creativecommons.org/licenses/by-nc-sa/4.0/
# 7   36.5130  http://creativecommons.org/licenses/by-nc-sa/3.0/
# 8   32.7257  http://creativecommons.org/licenses/by-nc-sa/4.0/
# 9   34.8464  http://creativecommons.org/licenses/by-nc-sa/4.0/
#
#                                             location  longitude  \
# 0  Cibola National Wildlife Refuge, Cibola, Arizo... -114.68912
# 1    Bill Williams River NWR, Arizona, United States -114.06900
# 2    Bill Williams River NWR, Arizona, United States -114.06900
# 3                      Salton Sea, CA, United States -115.79450
# 4      Sunset Park, Las Vegas, Nevada, United States -115.11280
# 5  Quigley Wildlife Management Area, Yuma County,... -113.95500
# 6  Quail Hollow, San Bernardino County, Californi... -114.15670
# 7   Overton WMA, Clark County, Nevada, United States -114.41800
# 8   Yuma East Wetlands, Yuma, Arizona, United States -114.60740
# 9  Pintail Slough, Havasu NWR, Mohave County, Ari... -114.52330
#
#             recordist                                      recordist_url  \
# 0      Nathan Pieplow  https://www.xeno-canto.org/contributor/EKKJJJRDJY
# 1       Lauren Harter  https://www.xeno-canto.org/contributor/YQNGFTBRRT
# 2       Lauren Harter  https://www.xeno-canto.org/contributor/YQNGFTBRRT
# 3       Peter Boesman  https://www.xeno-canto.org/contributor/OOECIWCSWV
# 4         Mike Nelson  https://www.xeno-canto.org/contributor/PWDLINYMKL
# 5   Richard E Webster  https://www.xeno-canto.org/contributor/KZYUWIRZVH
# 6       Lauren Harter  https://www.xeno-canto.org/contributor/YQNGFTBRRT
# 7   Ryan P. O'Donnell  https://www.xeno-canto.org/contributor/SDXVTLDNGJ
# 8        Bobby Wilcox  https://www.xeno-canto.org/contributor/YHKQPPJDVP
# 9  David Vander Pluym  https://www.xeno-canto.org/contributor/IBYEFBUOWZ
#
#                                         sonogram_url species  \
# 0  https://www.xeno-canto.org/sounds/uploaded/EKK...  aberti
# 1  https://www.xeno-canto.org/sounds/uploaded/YQN...  aberti
# 2  https://www.xeno-canto.org/sounds/uploaded/YQN...  aberti
# 3  https://www.xeno-canto.org/sounds/uploaded/OOE...  aberti
# 4  https://www.xeno-canto.org/sounds/uploaded/PWD...  aberti
# 5  https://www.xeno-canto.org/sounds/uploaded/KZY...  aberti
# 6  https://www.xeno-canto.org/sounds/uploaded/YQN...  aberti
# 7  https://www.xeno-canto.org/sounds/uploaded/SDX...  aberti
# 8  https://www.xeno-canto.org/sounds/uploaded/YHK...  aberti
# 9  https://www.xeno-canto.org/sounds/uploaded/IBY...  aberti
#
#                type                                            remarks  \
# 0       'seet' call  XC17804 © Nathan Pieplow // Cibola National Wi...
# 1              call  XC177367 © Lauren Harter // Bill Williams Rive...
# 2       Squeal duet  XC145505 © Lauren Harter // Bill Williams Rive...
# 3  interaction duet  XC228159 © Peter Boesman // Salton Sea, CA, Un...
# 4              call  XC51313 © Mike Nelson // Sunset Park, Las Vega...
# 5              call  XC111831 © Richard E Webster // Quigley Wildli...
# 6              call  XC289047 © Lauren Harter // Quail Hollow, San ...
# 7              call  XC119222 © Ryan P. O'Donnell // Overton WMA, C...
# 8              call  XC314730 © Bobby Wilcox // Yuma East Wetlands,...
# 9              call  XC288434 © David Vander Pluym // Pintail Sloug...
#
#                                      full_name fil_ename
# 0             Abert's Towhee (Melozone aberti)   XC17804
# 1  Abert's Towhee (Melozone aberti dumeticola)  XC177367
# 2  Abert's Towhee (Melozone aberti dumeticola)  XC145505
# 3             Abert's Towhee (Melozone aberti)  XC228159
# 4  Abert's Towhee (Melozone aberti dumeticola)   XC51313
# 5      Abert's Towhee (Melozone aberti aberti)  XC111831
# 6             Abert's Towhee (Melozone aberti)  XC289047
# 7             Abert's Towhee (Melozone aberti)  XC119222
# 8             Abert's Towhee (Melozone aberti)  XC314730
# 9             Abert's Towhee (Melozone aberti)  XC288434

# %%
extracted_Features=[]
from tqdm import tqdm
# Now we iterate through every audio file and extract features 
# using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(df.iterrows()):
    file_name = "wav_files"+'/'+str(row["file_name"])
    final_class_labels=row["full_name"]
    data=extraction(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 2730it [10:10,  4.47it/s]

# %%
df_2=pd.DataFrame(extracted_features,columns=["features","class"])
df_2.head(100)
# Out:
#                                              features  \
# 0   [-487.84076, 100.76654, 20.344347, 19.162067, ...
# 1   [-335.22678, 47.52835, -35.602505, 34.629467, ...
# 2   [-324.52283, 5.967165, -43.94186, 6.392367, -4...
# 3   [-265.413, 51.80022, -65.16458, 50.9011, -8.60...
# 4   [-224.79636, 62.386906, -18.460598, 28.302397,...
# ..                                                ...
# 95  [-281.3906, 133.28459, -13.674233, -24.947638,...
# 96  [-300.98874, 123.81023, -52.66742, -10.3443165...
# 97  [-362.33688, 91.81131, -35.630093, -7.204161, ...
# 98  [-213.91257, 70.96471, -57.61374, -10.669473, ...
# 99  [-229.29774, 130.59116, -58.791893, 8.48671, -...
#
#                                           class
# 0              Abert's Towhee (Melozone aberti)
# 1   Abert's Towhee (Melozone aberti dumeticola)
# 2   Abert's Towhee (Melozone aberti dumeticola)
# 3              Abert's Towhee (Melozone aberti)
# 4   Abert's Towhee (Melozone aberti dumeticola)
# ..                                          ...
# 95        American Crow (Corvus brachyrhynchos)
# 96        American Crow (Corvus brachyrhynchos)
# 97        American Crow (Corvus brachyrhynchos)
# 98        American Crow (Corvus brachyrhynchos)
# 99        American Crow (Corvus brachyrhynchos)
#
# [100 rows x 2 columns]

# %%
# Out:
# 5460

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
display=Tk()
display.title("Audio_Classifier")
display.minsize(width=1100,height=500)

l1=Label(display,text="Select from below to view their spectograms!",fg="purple",bg="lightblue",font=("Times 20 bold"))
l1.pack()

listbox2= Listbox(display, selectmode=SINGLE, height=5)
listbox2.place(x=450,y=110)
 

def selection(event):
    selected_index = listbox2.curselection()
    if selected_index:
        selected_option = listbox2.get(selected_index)
    y, sr = librosa.load(selected_option)  # Load with the original sample rate

    # Compute the Short-Time Fourier Transform (STFT) to get the spectrogram
    D = librosa.stft(y)  # Complex-valued spectrogram
    D_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)  # Convert to decibels for visualization

    fig, axs = plt.subplots(figsize=(6, 4)) 
    
    librosa.display.specshow(D_db, sr=sr, x_axis="time", y_axis="log")  # Log scale on y-axis 
    canvas = FigureCanvasTkAgg(fig, master=display)
    canvas_widget = canvas.get_tk_widget()
    

    canvas_widget.place(x=100,y=200)    
      
listbox2.bind("<<ListboxSelect>>", selection) 
c=0        
for i in features:
    c+=1
    listbox2.insert(END, str(i))
    if c==100:
        break
        


    
display.mainloop()
